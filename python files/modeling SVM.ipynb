# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from multiprocessing import Pool
import pickle
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# # Get data locations(path)

# %%
path_to_features_list = ['features/'+i for i in os.listdir('features')] + \
                         ['extra_features/'+i for i in os.listdir('extra_features')] + \
                        ['pos_features/'+i for i in os.listdir('pos_features')] 
print(len(path_to_features_list))
# Out:
# 32

# %%
data = pickle.load(open(path_to_features_list[0], 'rb'))
X_train = data['X_train']
y_train = data['y_train']
X_test = data['X_test']
y_test = data['y_test']

print(y_train.value_counts(), "\n\n", y_test.value_counts())
# Out:
# 3    8716
# 1    6285
# Name: Label_num, dtype: int64
#
#  1    630
# 3    286
# Name: Label_num, dtype: int64

# %% [markdown]
# # RUN models and save accuracy

# %%
def pickler_function(estimator, grid_label, save_path, feature_path):
    model = estimator
    data = pickle.load(open(feature_path, 'rb'))
    X_train = data['X_train']
    y_train = data['y_train']
    X_test = data['X_test']
    y_test = data['y_test']
#     print(model)
#     return
    print("Trying to fit", save_path, X_train.shape)
    # %time model.fit(X_train, y_train)
    evaluation_dict = {'Criteria': ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 score', 'Confusion Matrix']}
    print("Finished fitting", save_path)
    y_pred = model.predict(X_test)
    print("Finished predicting", save_path)
    evaluation_dict[grid_label] = [
                                    model,
                                    accuracy_score(y_test, y_pred),
                                    precision_score(y_test, y_pred, average='weighted'),
                                    recall_score(y_test, y_pred, average='weighted'),
                                    f1_score(y_test, y_pred, average='weighted'),
                                    confusion_matrix(y_test, y_pred)
                                    ]
    print("Finished evaluating", save_path)
    pickle.dump(evaluation_dict, open(save_path, 'wb'))
    print("Dumping successful for", save_path)

# %% [markdown]
# # Change for different classifiers

# %%
# %%time

num_load_features_at_once = 50
# copy_of_path_to_features_list = list(path_to_features_list)
force_write = True
process_pool = Pool(processes=num_load_features_at_once)
c_value = {'rbf': 1, 'linear': 1}
write_folder = 'results/SVM_brown/'

#empty directory
for path in os.listdir(write_folder):
    if os.path.isfile(os.path.join(write_folder, path)):
        os.remove(os.path.join(write_folder, path))
        print("Removed", path)
    
for read_path in path_to_features_list:
    write_path = write_folder + read_path.split('/')[-1]
    if os.path.isfile(write_path) and not force_write:
        print(write_path, "already exists. Moving on........\n\n")
        continue
    process_pool.apply_async(pickler_function, args=(
                                                    SVC(C=c_value['linear'], kernel='linear'),
                                                    'SVM_linear',
                                                    write_path,
                                                    read_path
                                                    )
                            )
process_pool.close()
process_pool.join()
print("Completed.")
# Out:
# Trying to fit results/SVM_brown/trigram.pickle (15001, 11240)
# Trying to fit results/SVM_brown/quadgram.pickle (15001, 5320)
# Trying to fit results/SVM_brown/3-4_gram.pickle (15001, 16560)
# Trying to fit results/SVM_brown/fivegram.pickle (15001, 4265)
# Trying to fit results/SVM_brown/bigram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/unigram.pickle (15001, 8656)
# Removed char_3_gram_non_alphabet.pickle
# Removed capitals_char_1_gram.pickle
# Removed 1-3_gram_without_stopwords.pickle
# Removed 7-7_char_gram.pickle
# Removed capitals_char_3_gram.pickle
# Removed quadgram.pickle
# Removed char_7_gram_non_alphabet.pickle
# Removed 5-6_char_gram.pickle
# Removed char_1_gram_non_alphabet.pickle
# Removed 1-1_char_gram.pickle
# Removed capitals_char_8_gram.pickle
# Removed trigram.pickle
# Removed capitals_char_6_gram.pickle
# Removed 3-4_gram.pickle
# Removed capitals_char_2_gram.pickle
# Removed capitals_char_4_gram.pickle
# Removed bigram_without_stopwords.pickle
# Removed quadgram_without_stopwords.pickle
# Removed 3-4_gram_without_stopwords.pickle
# Removed 6-6_char_gram.pickle
# Removed fivegram.pickle
# Removed 2-4_gram_without_stopwords.pickle
# Removed fivegram_without_stopwords.pickle
# Removed bigram.pickle
# Removed capitals_char_7_gram.pickle
# Removed unigram_without_stopwords.pickle
# Removed trigram_without_stopwords.pickle
# Removed 7-8_char_gram.pickle
# Removed 2-2_char_gram.pickle
# Removed 6-8_char_gram.pickle
# Removed 1-2_gram.pickle
# Removed unigram.pickle
# Removed 2-3_gram.pickle
# Removed 1-2_gram_without_stopwords.pickle
# Removed char_8_gram_non_alphabet.pickle
# Removed char_5_gram_non_alphabet.pickle
# Removed 2-4_gram.pickle
# Removed 1-2_char_gram.pickle
# Removed char_6_gram_non_alphabet.pickle
# Removed 1-4_gram.pickle
# Removed 8-8_char_gram.pickle
# Removed 6-7_char_gram.pickle
# Removed 1-4_gram_without_stopwords.pickle
# Removed 1-3_gram.pickle
# Removed 5-5_char_gram.pickle
# Removed 2-3_gram_without_stopwords.pickle
# Removed char_2_gram_non_alphabet.pickle
# Removed char_4_gram_non_alphabet.pickle
# Removed capitals_char_5_gram.pickle
# Trying to fit results/SVM_brown/1-3_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/2-3_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/2-4_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/2-5_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/1-1_char_gram.pickle (15001, 284)
# Trying to fit results/SVM_brown/1-4_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/1-2_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/2-2_char_gram.pickle (15001, 2277)
# Trying to fit results/SVM_brown/3-3_char_gram.pickle (15001, 11948)
# Trying to fit results/SVM_brown/2-3_char_gram.pickle (15001, 14225)
# Trying to fit results/SVM_brown/1-2_char_gram.pickle (15001, 2561)
# Trying to fit results/SVM_brown/1-3_char_gram.pickle (15001, 14509)
# Trying to fit results/SVM_brown/3-4_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/3-5_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/3-6_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/3-7_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/1-5_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/2-6_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/1-4_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/3-8_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/2-4_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/1-7_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/2-8_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/1-6_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/2-7_char_gram.pickle (15001, 20000)
# Trying to fit results/SVM_brown/1-8_char_gram.pickle (15001, 20000)
# CPU times: user 2.14 s, sys: 292 ms, total: 2.43 s
# Wall time: 2.43 s
# Finished fitting results/SVM_brown/fivegram.pickle
# Finished predicting results/SVM_brown/fivegram.pickle
# Finished evaluating results/SVM_brown/fivegram.pickle
# Dumping successful for results/SVM_brown/fivegram.pickle
# CPU times: user 3.91 s, sys: 428 ms, total: 4.34 s
# Wall time: 4.34 s
# Finished fitting results/SVM_brown/quadgram.pickle
# Finished predicting results/SVM_brown/quadgram.pickle
# Finished evaluating results/SVM_brown/quadgram.pickle
# Dumping successful for results/SVM_brown/quadgram.pickle
# CPU times: user 8.93 s, sys: 412 ms, total: 9.34 s
# Wall time: 9.35 s
# Finished fitting results/SVM_brown/trigram.pickle
# Finished predicting results/SVM_brown/trigram.pickle
# Finished evaluating results/SVM_brown/trigram.pickle
# Dumping successful for results/SVM_brown/trigram.pickle
# CPU times: user 9.46 s, sys: 440 ms, total: 9.9 s
# Wall time: 9.91 s
# Finished fitting results/SVM_brown/3-4_gram.pickle
# Finished predicting results/SVM_brown/3-4_gram.pickle
# Finished evaluating results/SVM_brown/3-4_gram.pickle
# Dumping successful for results/SVM_brown/3-4_gram.pickle
# CPU times: user 1min 17s, sys: 816 ms, total: 1min 18s
# Wall time: 1min 18s
# Finished fitting results/SVM_brown/2-3_gram.pickle
# Finished predicting results/SVM_brown/2-3_gram.pickle
# Finished evaluating results/SVM_brown/2-3_gram.pickle
# Dumping successful for results/SVM_brown/2-3_gram.pickle
# CPU times: user 1min 21s, sys: 592 ms, total: 1min 22s
# Wall time: 1min 22s
# Finished fitting results/SVM_brown/2-4_gram.pickle
# Finished predicting results/SVM_brown/2-4_gram.pickle
# Finished evaluating results/SVM_brown/2-4_gram.pickle
# Dumping successful for results/SVM_brown/2-4_gram.pickle
# CPU times: user 1min 39s, sys: 1.14 s, total: 1min 40s
# Wall time: 1min 40s
# Finished fitting results/SVM_brown/bigram.pickle
# CPU times: user 1min 40s, sys: 504 ms, total: 1min 40s
# Wall time: 1min 40s
# Finished fitting results/SVM_brown/unigram.pickle
# Finished predicting results/SVM_brown/bigram.pickle
# Finished evaluating results/SVM_brown/bigram.pickle
# Dumping successful for results/SVM_brown/bigram.pickle
# Finished predicting results/SVM_brown/unigram.pickle
# Finished evaluating results/SVM_brown/unigram.pickle
# Dumping successful for results/SVM_brown/unigram.pickle
# CPU times: user 1min 48s, sys: 616 ms, total: 1min 49s
# Wall time: 1min 49s
# Finished fitting results/SVM_brown/1-1_char_gram.pickle
# Finished predicting results/SVM_brown/1-1_char_gram.pickle
# Finished evaluating results/SVM_brown/1-1_char_gram.pickle
# Dumping successful for results/SVM_brown/1-1_char_gram.pickle
# CPU times: user 2min 31s, sys: 552 ms, total: 2min 31s
# Wall time: 2min 31s
# Finished fitting results/SVM_brown/1-3_gram.pickle
# Finished predicting results/SVM_brown/1-3_gram.pickle
# Finished evaluating results/SVM_brown/1-3_gram.pickle
# Dumping successful for results/SVM_brown/1-3_gram.pickle
# CPU times: user 2min 39s, sys: 560 ms, total: 2min 40s
# Wall time: 2min 40s
# Finished fitting results/SVM_brown/1-2_gram.pickle
# Finished predicting results/SVM_brown/1-2_gram.pickle
# Finished evaluating results/SVM_brown/1-2_gram.pickle
# Dumping successful for results/SVM_brown/1-2_gram.pickle
# CPU times: user 2min 52s, sys: 564 ms, total: 2min 52s
# Wall time: 2min 52s
# Finished fitting results/SVM_brown/1-4_gram.pickle
# Finished predicting results/SVM_brown/1-4_gram.pickle
# Finished evaluating results/SVM_brown/1-4_gram.pickle
# Dumping successful for results/SVM_brown/1-4_gram.pickle
# CPU times: user 4min 5s, sys: 584 ms, total: 4min 6s
# Wall time: 4min 6s
# Finished fitting results/SVM_brown/2-2_char_gram.pickle
# Finished predicting results/SVM_brown/2-2_char_gram.pickle
# Finished evaluating results/SVM_brown/2-2_char_gram.pickle
# Dumping successful for results/SVM_brown/2-2_char_gram.pickle
# CPU times: user 4min 50s, sys: 1.38 s, total: 4min 52s
# Wall time: 4min 52s
# Finished fitting results/SVM_brown/3-3_char_gram.pickle
# CPU times: user 4min 51s, sys: 808 ms, total: 4min 52s
# Wall time: 4min 52s
# Finished fitting results/SVM_brown/1-2_char_gram.pickle
# Finished predicting results/SVM_brown/1-2_char_gram.pickle
# Finished evaluating results/SVM_brown/1-2_char_gram.pickle
# Dumping successful for results/SVM_brown/1-2_char_gram.pickle
# Finished predicting results/SVM_brown/3-3_char_gram.pickle
# Finished evaluating results/SVM_brown/3-3_char_gram.pickle
# Dumping successful for results/SVM_brown/3-3_char_gram.pickle
# CPU times: user 6min 17s, sys: 932 ms, total: 6min 18s
# Wall time: 6min 18s
# Finished fitting results/SVM_brown/2-3_char_gram.pickle
# Finished predicting results/SVM_brown/2-3_char_gram.pickle
# Finished evaluating results/SVM_brown/2-3_char_gram.pickle
# Dumping successful for results/SVM_brown/2-3_char_gram.pickle
# CPU times: user 6min 47s, sys: 1.21 s, total: 6min 48s
# Wall time: 6min 49s
# Finished fitting results/SVM_brown/3-4_char_gram.pickle
# Finished predicting results/SVM_brown/3-4_char_gram.pickle
# Finished evaluating results/SVM_brown/3-4_char_gram.pickle
# Dumping successful for results/SVM_brown/3-4_char_gram.pickle
# CPU times: user 7min 5s, sys: 1.36 s, total: 7min 7s
# Wall time: 7min 7s
# Finished fitting results/SVM_brown/1-3_char_gram.pickle
# Finished predicting results/SVM_brown/1-3_char_gram.pickle
# Finished evaluating results/SVM_brown/1-3_char_gram.pickle
# Dumping successful for results/SVM_brown/1-3_char_gram.pickle
# CPU times: user 7min 37s, sys: 1.04 s, total: 7min 38s
# Wall time: 7min 38s
# Finished fitting results/SVM_brown/3-5_char_gram.pickle
# Finished predicting results/SVM_brown/3-5_char_gram.pickle
# Finished evaluating results/SVM_brown/3-5_char_gram.pickle
# Dumping successful for results/SVM_brown/3-5_char_gram.pickle
# CPU times: user 7min 55s, sys: 1.24 s, total: 7min 56s
# Wall time: 7min 56s
# Finished fitting results/SVM_brown/3-6_char_gram.pickle
# CPU times: user 7min 59s, sys: 1.49 s, total: 8min 1s
# Finished fitting results/SVM_brown/2-4_char_gram.pickle
# Wall time: 8min 1s
# CPU times: user 8min 6s, sys: 1.35 s, total: 8min 7s
# Wall time: 8min 7s
# Finished fitting results/SVM_brown/3-8_char_gram.pickle
# Finished predicting results/SVM_brown/3-6_char_gram.pickle
# Finished evaluating results/SVM_brown/3-6_char_gram.pickle
# Dumping successful for results/SVM_brown/3-6_char_gram.pickle
# CPU times: user 8min 13s, sys: 1.32 s, total: 8min 14s
# Wall time: 8min 14s
# Finished fitting results/SVM_brown/3-7_char_gram.pickle
# Finished predicting results/SVM_brown/2-4_char_gram.pickle
# Finished evaluating results/SVM_brown/2-4_char_gram.pickle
# Dumping successful for results/SVM_brown/2-4_char_gram.pickle
# Finished predicting results/SVM_brown/3-8_char_gram.pickle
# Finished evaluating results/SVM_brown/3-8_char_gram.pickle
# Dumping successful for results/SVM_brown/3-8_char_gram.pickle
# CPU times: user 8min 23s, sys: 1.41 s, total: 8min 24s
# Wall time: 8min 24s
# Finished fitting results/SVM_brown/1-4_char_gram.pickle
# Finished predicting results/SVM_brown/3-7_char_gram.pickle
# Finished evaluating results/SVM_brown/3-7_char_gram.pickle
# Dumping successful for results/SVM_brown/3-7_char_gram.pickle
# CPU times: user 8min 32s, sys: 1.11 s, total: 8min 34s
# Wall time: 8min 34s
# Finished fitting results/SVM_brown/2-5_char_gram.pickle
# Finished predicting results/SVM_brown/1-4_char_gram.pickle
# Finished evaluating results/SVM_brown/1-4_char_gram.pickle
# Dumping successful for results/SVM_brown/1-4_char_gram.pickle
# Finished predicting results/SVM_brown/2-5_char_gram.pickle
# Finished evaluating results/SVM_brown/2-5_char_gram.pickle
# Dumping successful for results/SVM_brown/2-5_char_gram.pickle
# CPU times: user 8min 59s, sys: 2.19 s, total: 9min 2s
# Wall time: 9min 2s
# Finished fitting results/SVM_brown/2-7_char_gram.pickle
# CPU times: user 9min 9s, sys: 1.18 s, total: 9min 10s
# Wall time: 9min 10s
# Finished fitting results/SVM_brown/2-6_char_gram.pickle
# CPU times: user 9min 16s, sys: 1.41 s, total: 9min 17s
# Wall time: 9min 17s
# Finished fitting results/SVM_brown/1-5_char_gram.pickle
# Finished predicting results/SVM_brown/2-7_char_gram.pickle
# Finished evaluating results/SVM_brown/2-7_char_gram.pickle
# Dumping successful for results/SVM_brown/2-7_char_gram.pickle
# CPU times: user 9min 18s, sys: 1.34 s, total: 9min 19s
# Wall time: 9min 19s
# Finished fitting results/SVM_brown/2-8_char_gram.pickle
# Finished predicting results/SVM_brown/2-6_char_gram.pickle
# Finished evaluating results/SVM_brown/2-6_char_gram.pickle
# Dumping successful for results/SVM_brown/2-6_char_gram.pickle
# Finished predicting results/SVM_brown/1-5_char_gram.pickle
# Finished evaluating results/SVM_brown/1-5_char_gram.pickle
# Dumping successful for results/SVM_brown/1-5_char_gram.pickle
# CPU times: user 9min 33s, sys: 1.87 s, total: 9min 35s
# Wall time: 9min 35s
# Finished fitting results/SVM_brown/1-6_char_gram.pickle
# Finished predicting results/SVM_brown/2-8_char_gram.pickle
# Finished evaluating results/SVM_brown/2-8_char_gram.pickle
# Dumping successful for results/SVM_brown/2-8_char_gram.pickle
# CPU times: user 9min 38s, sys: 1.36 s, total: 9min 40s
# Wall time: 9min 40s
# Finished fitting results/SVM_brown/1-7_char_gram.pickle
# CPU times: user 9min 42s, sys: 2.21 s, total: 9min 44s
# Wall time: 9min 44s
# Finished fitting results/SVM_brown/1-8_char_gram.pickle
# Finished predicting results/SVM_brown/1-6_char_gram.pickle
# Finished evaluating results/SVM_brown/1-6_char_gram.pickle
# Dumping successful for results/SVM_brown/1-6_char_gram.pickle
# Finished predicting results/SVM_brown/1-7_char_gram.pickle
# Finished evaluating results/SVM_brown/1-7_char_gram.pickle
# Dumping successful for results/SVM_brown/1-7_char_gram.pickle
# Finished predicting results/SVM_brown/1-8_char_gram.pickle
# Finished evaluating results/SVM_brown/1-8_char_gram.pickle
# Dumping successful for results/SVM_brown/1-8_char_gram.pickle
# Completed.
# CPU times: user 2.75 s, sys: 1.48 s, total: 4.22 s
# Wall time: 10min 3s
