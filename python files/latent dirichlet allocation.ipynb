# %% [markdown]
# # Imports

# %%
#all imports
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from IPython.display import display
from nltk import TweetTokenizer
import pickle
import os
from lda import LDA
from scipy.sparse import hstack
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# # label conversion dictionaries: text to num, num to text

# %%
dic_aggression_level = {
    'NAG' : 1,
    'CAG' : 2,
    'OAG' : 3
}

dic_reverse_aggression_level = {}
for i in dic_aggression_level:
    dic_reverse_aggression_level[dic_aggression_level[i]] = i
    
print(dic_aggression_level, '\n', dic_reverse_aggression_level)
# Out:
# {'OAG': 3, 'NAG': 1, 'CAG': 2}
#  {1: 'NAG', 2: 'CAG', 3: 'OAG'}

# %% [markdown]
# PREPARING DATA WITH PANDAS
# ----

# %%
#train data
train_pd = shuffle(pd.concat((pd.read_csv("train.csv")[['Data', 'Label']], pd.read_csv("valid.csv")[['Data', 'Label']])), random_state=20)
# train_pd['Label'].replace('CAG', 'OAG', inplace=True)
train_pd['Label_num'] = train_pd.Label.map(dic_aggression_level)

#test data
# test_fb_pd = shuffle(pd.read_csv("test_fb.csv")[['Data', 'Label']], random_state=20)
# test_fb_pd['Label_num'] = test_fb_pd.Label.map(dic_aggression_level)
# test_tw_pd = shuffle(pd.read_csv("test_tw.csv")[['Data', 'Label']], random_state=20)
# test_tw_pd['Label_num'] = test_tw_pd.Label.map(dic_aggression_level)

#test data
test_pd = pd.read_csv("test_fb.csv")
test_pd.drop('ID',1,inplace=True)
test_pd = shuffle(test_pd, random_state = 20)

# merge binary classification (CAG -> OAG)
# test_pd['Label'].replace('CAG', 'OAG', inplace=True)

test_pd['Label_num'] = test_pd.Label.map(dic_aggression_level)



print("\n\n\nTEST DATA")
print(test_pd.Label.value_counts())
display(test_pd.head(10))

#individual classes
class_wise_train_data = {}

class_wise_test_data = {}

for i in range(1,4):
    class_wise_train_data[i] = train_pd[(train_pd['Label_num']==i)]
    class_wise_test_data[i] = test_pd[(test_pd['Label_num']==i)]
    print(class_wise_train_data[i].Label.value_counts())
    display(class_wise_train_data[i].head(10))
    print(class_wise_test_data[i].Label.value_counts())
    display(class_wise_test_data[i].head(10))
# Out:
# TEST DATA
# NAG    630
# OAG    144
# CAG    142
# Name: Label, dtype: int64
#                                                   Data Label  Label_num
# 156           What will be done to the money we have ?   NAG          1
# 211  Unchange the rapo rate could lead the stagnate...   NAG          1
# 13   PK Movie Bhagawan Shiv Ko Aapman Kiya..   I Ha...   NAG          1
# 798  Thousands of people have died due to bandhs an...   CAG          2
# 640  Worst F.M ever.what about 5  lakhs tax limit? ...   NAG          1
# 568  Pak army rape modi daughter and go back. Now m...   NAG          1
# 321  I am clean without cash as transactions are th...   NAG          1
# 119  I have 5000 shares of Pnb @75.90 please tell m...   NAG          1
# 820  these bhagwa terrorists can't digest their mea...   OAG          3
# 721  Worst Decision and very worst implementation. ...   OAG          3
# NAG    6285
# Name: Label, dtype: int64
#                                                     Data Label  Label_num
# 5090   Sonia I am holding Rel cap 430, please suggest...   NAG          1
# 7272   Car is good.. bt i must say.. i only heard 'aa...   NAG          1
# 11474  till now India is stuck wheather the muslims a...   NAG          1
# 6979   Thank God ...what about navigation system and ...   NAG          1
# 391    BJP running MCD for ten years.  If people stil...   NAG          1
# 4029   What are the prospects for the Auto and Auto A...   NAG          1
# 4314   How soon do you think, the 5G will go live in ...   NAG          1
# 2428   Ask smith??? He said india will never gonna wi...   NAG          1
# 11012  Well we should keep in mind Baba's word Saurab...   NAG          1
# 2916   the first industrial revolution in india was b...   NAG          1
# NAG    630
# Name: Label, dtype: int64
#                                                   Data Label  Label_num
# 156           What will be done to the money we have ?   NAG          1
# 211  Unchange the rapo rate could lead the stagnate...   NAG          1
# 13   PK Movie Bhagawan Shiv Ko Aapman Kiya..   I Ha...   NAG          1
# 640  Worst F.M ever.what about 5  lakhs tax limit? ...   NAG          1
# 568  Pak army rape modi daughter and go back. Now m...   NAG          1
# 321  I am clean without cash as transactions are th...   NAG          1
# 119  I have 5000 shares of Pnb @75.90 please tell m...   NAG          1
# 524  Sir, I am looking for the this programme on TV...   NAG          1
# 365  Instead of watching this crap people shud show...   NAG          1
# 424  Name change won't change fortune of state. Was...   NAG          1
# CAG    5297
# Name: Label, dtype: int64
#                                                     Data Label  Label_num
# 2930   Focus on making cash available  then only  peo...   CAG          2
# 6769               Showing everything and saying bold...   CAG          2
# 10305  friends we have to understand the ground reali...   CAG          2
# 45                                        Bad...........   CAG          2
# 5374                                      Third rate dog   CAG          2
# 10762  All those who kill their wives or abandon them...   CAG          2
# 5611   His father did the right thing but the root ca...   CAG          2
# 5948                                      Poison  hasare   CAG          2
# 2036   Yes - it's a cash based economy so the steps d...   CAG          2
# 10261  B coz he is with B J P And lots of money.........   CAG          2
# CAG    142
# Name: Label, dtype: int64
#                                                   Data Label  Label_num
# 798  Thousands of people have died due to bandhs an...   CAG          2
# 797  Wow miracle  of modi  Manmohan  started  speaking   CAG          2
# 253  Yes yes ..traffic population pollution unlivab...   CAG          2
# 707  F. PM Manmohan Singh had 10 years now he has n...   CAG          2
# 684  Hello karki , How are you?A troll paid by BJP....   CAG          2
# 906  When asked to speak in Parliament ran away. Sp...   CAG          2
# 895  Pak Army intruded into Indian terrirtory, kill...   CAG          2
# 842  Modi is really tiger made them even dump once ...   CAG          2
# 751  The minister should also give swords to brideg...   CAG          2
# 731  How will it reduce black money ??? can anyone ...   CAG          2
# OAG    3419
# Name: Label, dtype: int64
#                                                    Data Label  Label_num
# 5103                   She's so ignorant Megha Mukherji   OAG          3
# 9074        why dont u make ur room sound proof..simple   OAG          3
# 140   Then what happens in pantry coach dedicated fo...   OAG          3
# 1756  We should respect every religion. May be he wa...   OAG          3
# 3168  It's like a devil think .. what tha hell is th...   OAG          3
# 9367  India is a fake, Fragile and unatural union bu...   OAG          3
# 2796  Police did the right thing . Indian express ha...   OAG          3
# 249                                         Cheap MLA..   OAG          3
# 4173           Triple Talak must be ban in india ......   OAG          3
# 2621          Corrupted old man.. ....one word for ANNA   OAG          3
# OAG    144
# Name: Label, dtype: int64
#                                                   Data Label  Label_num
# 820  these bhagwa terrorists can't digest their mea...   OAG          3
# 721  Worst Decision and very worst implementation. ...   OAG          3
# 819  Pakistanis are not human being. They are just ...   OAG          3
# 755  The most useless PM India ever seen, he could ...   OAG          3
# 748  Mr. Manmohan Singh...You are such a highly lea...   OAG          3
# 585  Omer Beigh you mean to say ,then they can talk...   OAG          3
# 688  Feeling proud to be a citizen of developing an...   OAG          3
# 412  ..Who is she anyway..her nonsense gets recogni...   OAG          3
# 693  Islam is not a religion and Allah is a big pie...   OAG          3
# 686  Even if modi ji farts, bhakts be like wow what...   OAG          3

# %%
def something(topics):
    lda_vect = LDA(n_topics=topics, n_iter=100)
    count_vect = CountVectorizer()
    tfidf_vect = TfidfVectorizer()

    count_train = count_vect.fit_transform(train_pd['Data'])
    lda_train = lda_vect.fit_transform(count_train)
    tfidf_train = tfidf_vect.fit_transform(train_pd['Data'])
    X_train = hstack([tfidf_train, lda_train])
    y_train = train_pd['Label_num']

    X_test = hstack([tfidf_vect.transform(test_pd['Data']), lda_vect.transform(count_vect.transform(test_pd['Data']))])
    y_test = test_pd['Label_num']

    svm = SVC(kernel='linear')
    svm.fit(X_train, train_pd['Label_num'])

    y_pred = svm.predict(X_test)

    print(topics, accuracy_score(y_test, y_pred), f1_score(y_test, y_pred, average='weighted'),
         confusion_matrix(y_test, y_pred))
    
from multiprocessing import Pool
process_pool = Pool(50)
process_pool.map(something, list(range(50, 301, 10)))
process_pool.close()
process_pool.join()
# something(20)
# Out:
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 180
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 210
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 130
# INFO:lda:n_iter: 100
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_topics: 50
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 110
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_documents: 15001
# INFO:lda:n_topics: 170
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_iter: 100
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 280
# INFO:lda:n_topics: 260
# INFO:lda:n_iter: 100
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 60
# INFO:lda:n_iter: 100
# INFO:lda:n_documents: 15001
# INFO:lda:n_documents: 15001
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:vocab_size: 24374
# INFO:lda:n_documents: 15001
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_words: 354658
# INFO:lda:vocab_size: 24374
# INFO:lda:vocab_size: 24374
# INFO:lda:n_topics: 240
# INFO:lda:n_topics: 270
# INFO:lda:n_words: 354658
# INFO:lda:n_iter: 100
# INFO:lda:n_iter: 100
# INFO:lda:n_topics: 230
# INFO:lda:n_words: 354658
# INFO:lda:n_iter: 100
# INFO:lda:n_topics: 190
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_documents: 15001
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_iter: 100
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_words: 354658
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:n_topics: 160
# INFO:lda:n_topics: 200
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 120
# INFO:lda:n_iter: 100
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 150
# INFO:lda:n_iter: 100
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:n_topics: 290
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 90
# INFO:lda:n_documents: 15001
# INFO:lda:n_iter: 100
# INFO:lda:n_documents: 15001
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 100
# INFO:lda:vocab_size: 24374
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 70
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero row in document-term matrix found
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:n_documents: 15001
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_words: 354658
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:n_topics: 300
# INFO:lda:n_topics: 80
# INFO:lda:n_documents: 15001
# INFO:lda:n_iter: 100
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_iter: 100
# INFO:lda:n_topics: 220
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:n_iter: 100
# WARNING:lda:all zero row in document-term matrix found
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# WARNING:lda:all zero row in document-term matrix found
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:n_documents: 15001
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 140
# INFO:lda:n_iter: 100
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# WARNING:lda:all zero row in document-term matrix found
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:n_documents: 15001
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:vocab_size: 24374
# INFO:lda:n_words: 354658
# INFO:lda:n_topics: 250
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:n_iter: 100
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# WARNING:lda:all zero row in document-term matrix found
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# /home/Abhor/.local/lib/python3.5/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:<0> log likelihood: -5105602
# INFO:lda:<0> log likelihood: -5257511
# INFO:lda:<0> log likelihood: -4937476
# INFO:lda:<0> log likelihood: -5232696
# INFO:lda:<0> log likelihood: -4994618
# INFO:lda:<0> log likelihood: -5158243
# INFO:lda:<0> log likelihood: -5247294
# INFO:lda:<0> log likelihood: -4724395
# INFO:lda:<0> log likelihood: -4870032
# INFO:lda:<0> log likelihood: -5271719
# INFO:lda:<0> log likelihood: -4655323
# INFO:lda:<0> log likelihood: -5282468
# INFO:lda:<0> log likelihood: -4780973
# INFO:lda:<0> log likelihood: -5019369
# INFO:lda:<0> log likelihood: -5204581
# INFO:lda:<0> log likelihood: -5124573
# INFO:lda:<0> log likelihood: -5065534
# INFO:lda:<0> log likelihood: -4904276
# INFO:lda:<0> log likelihood: -5043427
# INFO:lda:<0> log likelihood: -4827380
# INFO:lda:<0> log likelihood: -5087073
# INFO:lda:<0> log likelihood: -4965936
# INFO:lda:<0> log likelihood: -5189331
# INFO:lda:<0> log likelihood: -5140606
# INFO:lda:<0> log likelihood: -5173682
# INFO:lda:<0> log likelihood: -5218894
# INFO:lda:<10> log likelihood: -3276902
# INFO:lda:<10> log likelihood: -3303901
# INFO:lda:<10> log likelihood: -3353889
# INFO:lda:<20> log likelihood: -3144890
# INFO:lda:<10> log likelihood: -3334162
# INFO:lda:<20> log likelihood: -3166680
# INFO:lda:<30> log likelihood: -3083138
# INFO:lda:<10> log likelihood: -3416614
# INFO:lda:<10> log likelihood: -3384202
# INFO:lda:<10> log likelihood: -3400354
# INFO:lda:<20> log likelihood: -3208389
# INFO:lda:<10> log likelihood: -3456437
# INFO:lda:<40> log likelihood: -3051749
# INFO:lda:<30> log likelihood: -3106657
# INFO:lda:<20> log likelihood: -3192531
# INFO:lda:<50> log likelihood: -3031891
# INFO:lda:<10> log likelihood: -3440922
# INFO:lda:<10> log likelihood: -3509037
# INFO:lda:<10> log likelihood: -3542579
# INFO:lda:<30> log likelihood: -3149330
# INFO:lda:<60> log likelihood: -3015023
# INFO:lda:<10> log likelihood: -3482012
# INFO:lda:<20> log likelihood: -3226034
# INFO:lda:<40> log likelihood: -3076240
# INFO:lda:<20> log likelihood: -3263995
# INFO:lda:<10> log likelihood: -3489075
# INFO:lda:<30> log likelihood: -3130381
# INFO:lda:<20> log likelihood: -3246348
# INFO:lda:<70> log likelihood: -3003452
# INFO:lda:<10> log likelihood: -3581918
# INFO:lda:<10> log likelihood: -3525413
# INFO:lda:<40> log likelihood: -3113698
# INFO:lda:<20> log likelihood: -3297331
# INFO:lda:<50> log likelihood: -3057926
# INFO:lda:<10> log likelihood: -3551258
# INFO:lda:<80> log likelihood: -2997730
# INFO:lda:<40> log likelihood: -3095535
# INFO:lda:<10> log likelihood: -3565073
# INFO:lda:<20> log likelihood: -3278939
# INFO:lda:<10> log likelihood: -3641827
# INFO:lda:<10> log likelihood: -3626969
# INFO:lda:<30> log likelihood: -3158496
# INFO:lda:<90> log likelihood: -2990681
# INFO:lda:<60> log likelihood: -3040854
# INFO:lda:<30> log likelihood: -3197953
# INFO:lda:<10> log likelihood: -3594290
# INFO:lda:<30> log likelihood: -3178080
# INFO:lda:<10> log likelihood: -3654929
# INFO:lda:<50> log likelihood: -3092002
# INFO:lda:<10> log likelihood: -3666290
# INFO:lda:<20> log likelihood: -3342828
# INFO:lda:<50> log likelihood: -3070907
# INFO:lda:<10> log likelihood: -3619231
# INFO:lda:<99> log likelihood: -2984677
# INFO:lda:<10> log likelihood: -3607298
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<70> log likelihood: -3030397
# INFO:lda:<20> log likelihood: -3313099
# INFO:lda:<20> log likelihood: -3370448
# INFO:lda:<20> log likelihood: -3323475
# INFO:lda:<40> log likelihood: -3122951
# INFO:lda:<60> log likelihood: -3052719
# INFO:lda:<60> log likelihood: -3073397
# INFO:lda:<80> log likelihood: -3023236
# INFO:lda:<30> log likelihood: -3227007
# INFO:lda:<40> log likelihood: -3142807
# INFO:lda:<40> log likelihood: -3158856
# INFO:lda:<30> log likelihood: -3208900
# INFO:lda:<10> log likelihood: -3691547
# INFO:lda:<10> log likelihood: -3679477
# INFO:lda:<90> log likelihood: -3014541
# INFO:lda:<70> log likelihood: -3041099
# INFO:lda:<20> log likelihood: -3352877
# INFO:lda:<50> log likelihood: -3100963
# INFO:lda:<70> log likelihood: -3060975
# INFO:lda:<99> log likelihood: -3008055
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<20> log likelihood: -3379514
# INFO:lda:<20> log likelihood: -3409071
# INFO:lda:<80> log likelihood: -3031018
# INFO:lda:<50> log likelihood: -3121958
# INFO:lda:<30> log likelihood: -3268669
# INFO:lda:<30> log likelihood: -3242329
# INFO:lda:<20> log likelihood: -3388788
# INFO:lda:<40> log likelihood: -3190296
# INFO:lda:<40> log likelihood: -3170517
# INFO:lda:<80> log likelihood: -3051297
# INFO:lda:<50> log likelihood: -3135191
# INFO:lda:<30> log likelihood: -3254130
# INFO:lda:<60> log likelihood: -3085179
# INFO:lda:<90> log likelihood: -3024462
# INFO:lda:<30> log likelihood: -3296080
# INFO:lda:<20> log likelihood: -3416280
# INFO:lda:<20> log likelihood: -3445343
# INFO:lda:<20> log likelihood: -3428499
# INFO:lda:<90> log likelihood: -3043979
# INFO:lda:<99> log likelihood: -3017974
# INFO:lda:<20> log likelihood: -3445520
# INFO:lda:<60> log likelihood: -3107161
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<70> log likelihood: -3074916
# INFO:lda:<20> log likelihood: -3460192
# INFO:lda:<30> log likelihood: -3283514
# INFO:lda:<50> log likelihood: -3149160
# INFO:lda:<40> log likelihood: -3203334
# INFO:lda:<60> log likelihood: -3120625
# INFO:lda:<40> log likelihood: -3231797
# INFO:lda:<50> log likelihood: -3164827
# INFO:lda:<20> log likelihood: -3474855
# INFO:lda:<99> log likelihood: -3037505
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<30> log likelihood: -3307375
# INFO:lda:<70> log likelihood: -3093229
# INFO:lda:<80> log likelihood: -3065030
# INFO:lda:<20> log likelihood: -3486943
# INFO:lda:<40> log likelihood: -3214474
# INFO:lda:<30> log likelihood: -3334530
# INFO:lda:<70> log likelihood: -3105481
# INFO:lda:<30> log likelihood: -3319702
# INFO:lda:<60> log likelihood: -3130443
# INFO:lda:<40> log likelihood: -3255827
# INFO:lda:<90> log likelihood: -3059315
# INFO:lda:<20> log likelihood: -3496936
# INFO:lda:<60> log likelihood: -3150835
# INFO:lda:<50> log likelihood: -3178085
# INFO:lda:<80> log likelihood: -3086457
# INFO:lda:<20> log likelihood: -3506155
# INFO:lda:<40> log likelihood: -3238165
# INFO:lda:<30> log likelihood: -3341861
# INFO:lda:<50> log likelihood: -3204456
# INFO:lda:<50> log likelihood: -3191376
# INFO:lda:<80> log likelihood: -3096789
# INFO:lda:<99> log likelihood: -3052806
# INFO:lda:<30> log likelihood: -3355973
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<90> log likelihood: -3077215
# INFO:lda:<70> log likelihood: -3118528
# INFO:lda:<30> log likelihood: -3370998
# INFO:lda:<30> log likelihood: -3370522
# INFO:lda:<40> log likelihood: -3267633
# INFO:lda:<70> log likelihood: -3140278
# INFO:lda:<60> log likelihood: -3159964
# INFO:lda:<30> log likelihood: -3386250
# INFO:lda:<90> log likelihood: -3088666
# INFO:lda:<99> log likelihood: -3071846
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<40> log likelihood: -3298989
# INFO:lda:<40> log likelihood: -3281960
# INFO:lda:<50> log likelihood: -3231257
# INFO:lda:<80> log likelihood: -3109756
# INFO:lda:<50> log likelihood: -3218036
# INFO:lda:<60> log likelihood: -3174090
# INFO:lda:<30> log likelihood: -3401527
# INFO:lda:<60> log likelihood: -3188889
# INFO:lda:<80> log likelihood: -3129823
# INFO:lda:<30> log likelihood: -3409144
# INFO:lda:<70> log likelihood: -3150228
# INFO:lda:<99> log likelihood: -3083775
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<40> log likelihood: -3300330
# INFO:lda:<90> log likelihood: -3103510
# INFO:lda:<50> log likelihood: -3241766
# INFO:lda:<90> log likelihood: -3123382
# INFO:lda:<40> log likelihood: -3316661
# INFO:lda:<40> log likelihood: -3334222
# INFO:lda:<70> log likelihood: -3162152
# INFO:lda:<30> log likelihood: -3420897
# INFO:lda:<30> log likelihood: -3432351
# INFO:lda:<60> log likelihood: -3199236
# INFO:lda:<40> log likelihood: -3330464
# INFO:lda:<80> log likelihood: -3139956
# INFO:lda:<70> log likelihood: -3179618
# INFO:lda:<60> log likelihood: -3212000
# INFO:lda:<50> log likelihood: -3272313
# INFO:lda:<50> log likelihood: -3254874
# INFO:lda:<40> log likelihood: -3344707
# INFO:lda:<99> log likelihood: -3098414
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<99> log likelihood: -3115769
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<40> log likelihood: -3361882
# INFO:lda:<90> log likelihood: -3131988
# INFO:lda:<80> log likelihood: -3153638
# INFO:lda:<80> log likelihood: -3171186
# INFO:lda:<60> log likelihood: -3223651
# INFO:lda:<70> log likelihood: -3189739
# INFO:lda:<40> log likelihood: -3366029
# INFO:lda:<50> log likelihood: -3276910
# INFO:lda:<70> log likelihood: -3200718
# INFO:lda:<60> log likelihood: -3236893
# INFO:lda:<60> log likelihood: -3253375
# INFO:lda:<50> log likelihood: -3293607
# INFO:lda:<99> log likelihood: -3125674
# INFO:lda:<50> log likelihood: -3309624
# INFO:lda:<50> log likelihood: -3306926
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<90> log likelihood: -3146316
# INFO:lda:<50> log likelihood: -3322074
# INFO:lda:<90> log likelihood: -3161504
# INFO:lda:<80> log likelihood: -3181095
# INFO:lda:<40> log likelihood: -3380223
# INFO:lda:<40> log likelihood: -3392872
# INFO:lda:<80> log likelihood: -3190000
# INFO:lda:<70> log likelihood: -3210204
# INFO:lda:<60> log likelihood: -3259429
# INFO:lda:<50> log likelihood: -3334422
# INFO:lda:<99> log likelihood: -3138199
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<70> log likelihood: -3225241
# INFO:lda:<70> log likelihood: -3241439
# INFO:lda:<99> log likelihood: -3155622
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<50> log likelihood: -3344350
# INFO:lda:<90> log likelihood: -3172494
# INFO:lda:<60> log likelihood: -3290449
# INFO:lda:<60> log likelihood: -3277004
# INFO:lda:<60> log likelihood: -3291698
# INFO:lda:<90> log likelihood: -3184159
# INFO:lda:<80> log likelihood: -3201416
# INFO:lda:<60> log likelihood: -3305240
# INFO:lda:<80> log likelihood: -3216018
# INFO:lda:<70> log likelihood: -3249309
# INFO:lda:<99> log likelihood: -3162892
# INFO:lda:<50> log likelihood: -3357715
# INFO:lda:<80> log likelihood: -3230350
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<50> log likelihood: -3368315
# INFO:lda:<99> log likelihood: -3179294
# INFO:lda:<60> log likelihood: -3317869
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<70> log likelihood: -3262152
# INFO:lda:<70> log likelihood: -3275863
# INFO:lda:<90> log likelihood: -3192164
# INFO:lda:<60> log likelihood: -3322714
# INFO:lda:<70> log likelihood: -3280494
# INFO:lda:<90> log likelihood: -3208594
# INFO:lda:<80> log likelihood: -3240104
# INFO:lda:<90> log likelihood: -3221837
# INFO:lda:<70> log likelihood: -3292679
# 50 0.5611353711790393 0.6002687057611727 [[361 218  51]
#  [ 36  86  20]
#  [ 25  52  67]]
# INFO:lda:<60> log likelihood: -3342790
# INFO:lda:<80> log likelihood: -3250875
# INFO:lda:<99> log likelihood: -3188600
# INFO:lda:<80> log likelihood: -3262800
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<70> log likelihood: -3305089
# INFO:lda:<60> log likelihood: -3348743
# INFO:lda:<99> log likelihood: -3203445
# INFO:lda:<80> log likelihood: -3269930
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<70> log likelihood: -3313958
# INFO:lda:<99> log likelihood: -3217316
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<90> log likelihood: -3231540
# INFO:lda:<80> log likelihood: -3286472
# INFO:lda:<90> log likelihood: -3243885
# 60 0.5633187772925764 0.6033123461243413 [[362 221  47]
#  [ 40  83  19]
#  [ 23  50  71]]
# INFO:lda:<90> log likelihood: -3252166
# INFO:lda:<80> log likelihood: -3293514
# INFO:lda:<70> log likelihood: -3330243
# INFO:lda:<90> log likelihood: -3260520
# INFO:lda:<99> log likelihood: -3227235
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<80> log likelihood: -3302330
# INFO:lda:<70> log likelihood: -3339393
# INFO:lda:<90> log likelihood: -3277669
# INFO:lda:<99> log likelihood: -3240555
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# 70 0.5753275109170306 0.6127054529261785 [[370 211  49]
#  [ 36  86  20]
#  [ 26  47  71]]
# INFO:lda:<99> log likelihood: -3248677
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<99> log likelihood: -3253737
# INFO:lda:<90> log likelihood: -3286352
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<80> log likelihood: -3318582
# 80 0.5687772925764192 0.6073274173032666 [[363 218  49]
#  [ 32  90  20]
#  [ 25  51  68]]
# INFO:lda:<90> log likelihood: -3294742
# INFO:lda:<99> log likelihood: -3272966
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<80> log likelihood: -3328690
# INFO:lda:<99> log likelihood: -3280245
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<90> log likelihood: -3310508
# INFO:lda:<99> log likelihood: -3287119
# 90 0.5644104803493449 0.6027784366619292 [[360 221  49]
#  [ 33  89  20]
#  [ 27  49  68]]
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# INFO:lda:<90> log likelihood: -3322436
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/anaconda/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-5-d65016db9bf5>", line 18, in something
#     y_pred = svm.predict(X_test)
#   File "/home/Abhor/.local/lib/python3.5/site-packages/sklearn/svm/base.py", line 548, in predict
#     y = super(BaseSVC, self).predict(X)
#   File "/home/Abhor/.local/lib/python3.5/site-packages/sklearn/svm/base.py", line 308, in predict
#     X = self._validate_for_predict(X)
#   File "/home/Abhor/.local/lib/python3.5/site-packages/sklearn/svm/base.py", line 439, in _validate_for_predict
#     X = check_array(X, accept_sparse='csr', dtype=np.float64, order="C")
#   File "/home/Abhor/.local/lib/python3.5/site-packages/sklearn/utils/validation.py", line 431, in check_array
#     force_all_finite)
#   File "/home/Abhor/.local/lib/python3.5/site-packages/sklearn/utils/validation.py", line 306, in _ensure_sparse_format
#     _assert_all_finite(spmatrix.data)
#   File "/home/Abhor/.local/lib/python3.5/site-packages/sklearn/utils/validation.py", line 44, in _assert_all_finite
#     " or a value too large for %r." % X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d65016db9bf5> in <module>()
#      23 from multiprocessing import Pool
#      24 process_pool = Pool(50)
# ---> 25 process_pool.map(something, list(range(50, 301, 10)))
#      26 process_pool.close()
#      27 process_pool.join()
#
# /opt/anaconda/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /opt/anaconda/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
# INFO:lda:<99> log likelihood: -3306270
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# 110 0.5567685589519651 0.5958809365250254 [[356 223  51]
#  [ 34  87  21]
#  [ 27  50  67]]
# INFO:lda:<99> log likelihood: -3314037
# WARNING:lda:all zero row in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# 130 0.5611353711790393 0.6003646554263183 [[361 216  53]
#  [ 39  82  21]
#  [ 24  49  71]]
# 140 0.5622270742358079 0.6027769201836191 [[356 227  47]
#  [ 36  86  20]
#  [ 22  49  73]]
# 160 0.5513100436681223 0.5899359870596186 [[352 228  50]
#  [ 33  89  20]
#  [ 30  50  64]]
# 170 0.5600436681222707 0.5991123585224161 [[364 216  50]
#  [ 39  83  20]
#  [ 26  52  66]]
# 180 0.5622270742358079 0.6010760779125209 [[363 216  51]
#  [ 36  85  21]
#  [ 26  51  67]]
# 190 0.5491266375545851 0.5879646334114175 [[352 224  54]
#  [ 34  87  21]
#  [ 29  51  64]]
# 200 0.5600436681222707 0.5998154438077892 [[361 218  51]
#  [ 37  84  21]
#  [ 24  52  68]]
# 210 0.5622270742358079 0.6025036278084566 [[356 225  49]
#  [ 31  91  20]
#  [ 22  54  68]]
# 230 0.5644104803493449 0.6035819801268687 [[359 223  48]
#  [ 35  87  20]
#  [ 25  48  71]]
# 240 0.5545851528384279 0.5935124173280635 [[353 228  49]
#  [ 31  90  21]
#  [ 29  50  65]]
# 220 0.5622270742358079 0.6020467540550084 [[360 221  49]
#  [ 35  88  19]
#  [ 23  54  67]]
# 250 0.5589519650655022 0.5983432986783594 [[362 218  50]
#  [ 36  85  21]
#  [ 26  53  65]]
# 260 0.5600436681222707 0.5989823795801874 [[359 217  54]
#  [ 34  89  19]
#  [ 24  55  65]]
# 290 0.5600436681222707 0.5994216665520917 [[358 223  49]
#  [ 35  88  19]
#  [ 25  52  67]]
# 270 0.5644104803493449 0.6025041553150877 [[367 211  52]
#  [ 35  86  21]
#  [ 27  53  64]]
# 280 0.5644104803493449 0.604156870895062 [[364 218  48]
#  [ 36  85  21]
#  [ 24  52  68]]
# 300 0.5644104803493449 0.6029723221883481 [[365 215  50]
#  [ 37  85  20]
#  [ 26  51  67]]
